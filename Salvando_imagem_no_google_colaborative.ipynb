# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(20)
y = [x_i + np.random.randn(1) for x_i in x]
a, b = np.polyfit(x, y, 1)
f = plt.figure()
_ = plt.plot(x, y, 'o', np.arange(20), a*np.arange(20)+b, '-')

f.savefig( "test.png")

# %%
import os
print( os.getcwd() )
print( os.listdir() )
# Out:
# /content
# ['datalab', '.cache', 'data.csv', 'calibracao.csv', '.ipython', 'out.png', '.forever', 'dado_primeira_ordem.csv', 'dado_primeira_ordem (1).csv', 'test.png', '.config', '.local']

# %%
from google.colab import files
files.download( "test.png" )
